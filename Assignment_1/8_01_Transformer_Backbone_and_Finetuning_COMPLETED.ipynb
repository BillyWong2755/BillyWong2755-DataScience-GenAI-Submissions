# %% [markdown]
# <a href="https://colab.research.google.com/github/BillyWong2755/BillyWong2755-DataScience-GenAI-Submissions/blob/main/Assignment_1/8_01_Transformer_Backbone_and_Finetuning_COMPLETED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Have no idea why I can't save the copy in GitHub, so I save it in my own Colab drive:

# %%
# https://colab.research.google.com/drive/1R9Ch3REE8Z1mQWA0atTS3qP2CoLABCIG

# %%
# Conclusion:

# A good model requires a longer training time and a more significant computing power.
# This is why the first approach performs better as we enjoy the features provided by well-trained BERT. We build on top of it.
# I think it is also possible to do fine-tuning if we have a huge amount of data and significant power,
# but in general it is very difficult for a small model to compete with a large, well-trained one.
# We can consider using the first approach, if possible, when we are building a very complicated model.
